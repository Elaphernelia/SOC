# %% [markdown]
# #Proyecto final SOC
# ####Ela Katherine Shepherd Arévalo
# ####Belén García Puente
# ####Víctor Santamaría Gredilla
#
# En este notebook se hizo la primera etapa de limpieza de datos: Se eliminaron columnas y filas innecesarias (se pasó de 29503 a 22961 nodos)

# %%
import csv
import pandas as pd

# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
read_file = pd.read_excel (r'/content/gdrive/Shareddrives/SOC/Proyecto_Final/hot100.xlsx')
read_file.to_csv (r'/content/gdrive/Shareddrives/SOC/Proyecto_Final/hot100.csv', index = None, header=True)

# %%
df = pd.read_csv('/content/gdrive/Shareddrives/SOC/Proyecto_Final/hot100.csv')

# %%
df.shape
# Out:
# (29503, 22)

# %%
df
# Out:
#                                                   SongID  ... spotify_track_popularity
# 0         -twistin'-White Silver SandsBill Black's Combo  ...                      NaN
# 1      ¿Dònde Està Santa Claus? (Where Is Santa Claus...  ...                      NaN
# 2                 ......And Roses And RosesAndy Williams  ...                     38.0
# 3               ...And Then There Were DrumsSandy Nelson  ...                     11.0
# 4                    ...Baby One More TimeBritney Spears  ...                     77.0
# ...                                                  ...  ...                      ...
# 29498  Zoo YorkLil Tjay Featuring Fivio Foreign & Pop...  ...                      NaN
# 29499                                         ZoomFuture  ...                     51.0
# 29500                 ZoomLil' Boosie Featuring Yung Joc  ...                      NaN
# 29501     Zorba The GreekHerb Alpert & The Tijuana Brass  ...                     35.0
# ...

# %%
df = df[df['spotify_track_id'].notna()]
df = df[df['danceability'].notna()]
df = df[df['energy'].notna()]
df = df[df['loudness'].notna()]

# %%
df.shape
# Out:
# (24330, 22)

# %%
df.head(25)
# Out:
#                                                SongID  ... spotify_track_popularity
# 2              ......And Roses And RosesAndy Williams  ...                     38.0
# 3            ...And Then There Were DrumsSandy Nelson  ...                     11.0
# 4                 ...Baby One More TimeBritney Spears  ...                     77.0
# 5                        ...Ready For It?Taylor Swift  ...                     73.0
# 7                           '65 Love AffairPaul Davis  ...                     40.0
# 10          'til I Can Make It On My OwnTammy Wynette  ...                     31.0
# 12             'Til My Baby Comes HomeLuther Vandross  ...                     29.0
# 13                'Til Summer Comes AroundKeith Urban  ...                     42.0
# 14                        'Til You Do Me RightAfter 7  ...                     42.0
# 15                                     'TilThe Angels  ...                     10.0
# ...

# %%
df.drop(df.columns.difference(['Performer','Song','spotify_genre','spotify_track_id','danceability','energy','loudness','spotify_track_popularity', 'spotify_track_album']), 1, inplace=True)

# %%
df.shape
# Out:
# (24330, 9)

# %%
df.head(25)
# Out:
#               Performer  ... spotify_track_popularity
# 2         Andy Williams  ...                     38.0
# 3          Sandy Nelson  ...                     11.0
# 4        Britney Spears  ...                     77.0
# 5          Taylor Swift  ...                     73.0
# 7            Paul Davis  ...                     40.0
# 10        Tammy Wynette  ...                     31.0
# 12      Luther Vandross  ...                     29.0
# 13          Keith Urban  ...                     42.0
# 14              After 7  ...                     42.0
# 15           The Angels  ...                     10.0
# 16         Taylor Swift  ...                     70.0
# 17   Young And Restless  ...                     20.0
# 18         Neil Diamond  ...                     16.0
# 23  The Everly Brothers  ...                     53.0
# 27           Mel Carter  ...                     17.0
# 28            Paul Anka  ...                     21.0
# ...

# %%
df.shape
# Out:
# (24330, 9)

# %%
#Sabemos que hay que ver 22961 elementos porque anteriormente se hizo este bucle
#con 24397, el número de filas actual, pero daba un error de "index out of bounds"
#y si se comprobaba el nº de filas después, veíamos que era 22961
for x in range(22961):
    if (df.iloc[x]['spotify_genre'] == '[]'):
       df = df.drop(df.iloc[x].name)

# %%
df.shape
# Out:
# (22961, 9)

# %%
df.head(25)
#df en su estado actual es lo que queremos transformar en una red social
# Out:
#               Performer  ... spotify_track_popularity
# 2         Andy Williams  ...                     38.0
# 3          Sandy Nelson  ...                     11.0
# 4        Britney Spears  ...                     77.0
# 5          Taylor Swift  ...                     73.0
# 7            Paul Davis  ...                     40.0
# 10        Tammy Wynette  ...                     31.0
# 12      Luther Vandross  ...                     29.0
# 13          Keith Urban  ...                     42.0
# 14              After 7  ...                     42.0
# 15           The Angels  ...                     10.0
# 16         Taylor Swift  ...                     70.0
# 18         Neil Diamond  ...                     16.0
# 23  The Everly Brothers  ...                     53.0
# 28            Paul Anka  ...                     21.0
# 31         The Olympics  ...                      5.0
# 33         'Til Tuesday  ...                     17.0
# ...

# %%
df.to_csv('/content/gdrive/Shareddrives/SOC/Proyecto_Final/hot100_clean_test1.csv', index=False)
