# %% [markdown]
# # Introducción

# %% [markdown]
# Este Jupyter Notebook forma parte del proyecto de SOC 2021/2022 de la Facultad de Informática para la práctica 1, adjunto a la memoria de la práctica donde se realizan comparaciones con los resultados obtenidos empleando Gephi.
#
# El dataset empleado es una exportación del '.gephi' original de la red de Marvel citada en la página, empleando para los presentes cálculos el documento obtenido en formato '.graphml'
#
# Integrantes:
#   - Belén García Puente
#   - Ela Katherine Shepherd Arévalo
#   - Víctor Santamaría Gredilla

# %% [markdown]
# ***

# %%
#Imports
import networkx as nx
import numpy as np
import operator
import collections
import matplotlib.pyplot as plt
from community import community_louvain
# %matplotlib inline
#from networkx.algorithms.community import greedy_modularity_communities

#Decorator updated to v5.1 to avoid a known bug on indexes. Installation of python_louvain required

# %%
G = nx.read_graphml("marvelgraph.graphml")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ***
# # Información general

# %%
print(nx.info(G))
# Out:
# Graph with 10469 nodes and 178115 edges

# %%
# Número de componentes conexas
print("Componentes conexas:", nx.number_connected_components(G))
# Out:
# Componentes conexas: 8

# %% [markdown]
# ***
# # Centralidad de grado

# %%
# Centralidad de grado
degCent = nx.degree_centrality(G)

# %%
aux = sorted(G.degree, key=lambda x: x[1], reverse=True)[0:10]
for x in aux:
    print(G.nodes[x[0]]["label"], "=" ,x[1], "nodos")
# Out:
# IRON MAN/TONY STARK = 2189 nodos
# WOLVERINE/LOGAN = 1984 nodos
# CAPTAIN AMERICA = 1896 nodos
# SCARLET WITCH/WANDA = 1883 nodos
# VISION = 1765 nodos
# INVISIBLE WOMAN/SUE = 1750 nodos
# SPIDER-MAN/PETER PAR = 1730 nodos
# WASP/JANET VAN DYNE = 1517 nodos
# DR. STRANGE/STEPHEN = 1489 nodos
# PROFESSOR X/CHARLES = 1471 nodos

# %% [markdown]
# # Centralidad de intermediación

# %%
for node in G.nodes(data=True):
    print (node)
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# ('12978', {'label': 'CEREBRITE ALPHA', 'Eccentricity': 4.0, 'Closeness Centrality': 0.3662036062583316, 'Harmonic Closeness Centrality': 0.38111888111892694, 'Betweenness Centrality': 1.5087580858327773e-06, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 2.0381627, 'r': 115, 'g': 192, 'b': 0, 'x': 880.161, 'y': 35.54827})
# ('12979', {'label': 'CEREBRITE BETA', 'Eccentricity': 4.0, 'Closeness Centrality': 0.366280701754386, 'Harmonic Closeness Centrality': 0.3812466072740504, 'Betweenness Centrality': 2.4695145367632292e-06, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 2.0740402, 'r': 115, 'g': 192, 'b': 0, 'x': 822.9941, 'y': 61.566364})
# ('12980', {'label': 'CEREBRO', 'Eccentricity': 4.0, 'Closeness Centrality': 0.367272983147451, 'Harmonic Closeness Centrality': 0.3827952869049212, 'Betweenness Centrality': 7.220972993519015e-06, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 2.325183, 'r': 115, 'g': 192, 'b': 0, 'x': 1092.9211, 'y': 3.2046773})
# ('12981', {'label': ',"JONES, WILLIAM', 'Eccentricity': 5.0, 'Closeness Centrality': 0.319783114814361, 'Harmonic Closeness Centrality': 0.3386595140020035, 'Betweenness Centrality': 0.0, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.5, 'r': 115, 'g': 192, 'b': 0, 'x': 1217.0739, 'y': -276.9868})
# ('12982', {'label': 'JONES, WILLIAM', 'Eccentricity': 4.0, 'Closeness Centrality': 0.36139864981824477, 'Harmonic Closeness Centrality': 0.37495609413422254, 'Betweenness Centrality': 1.3373578793661381e-06, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.7870201, 'r': 115, 'g': 192, 'b': 0, 'x': 983.29016, 'y': 24.009844})
# ('12983', {'label': 'VINDALOO/', 'Eccentricity': 4.0, 'Closeness Centrality': 0.37823834196891193, 'Harmonic Closeness Centrality': 0.3959351151132387, 'Betweenness Centrality': 3.742316207915335e-06, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 3.186243, 'r': 115, 'g': 192, 'b': 0, 'x': 705.88586, 'y': 300.87})
# ('12984', {'label': 'UNUSCIONE', 'Eccentricity': 4.0, 'Closeness Centrality': 0.39779742397683104, 'Harmonic Closeness Centrality': 0.4182073634128667, 'Betweenness Centrality': 4.920612493591502e-05, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 3.2938757, 'r': 115, 'g': 192, 'b': 0, 'x': 235.84512, 'y': 431.42886})
# ('12985', {'label': 'KAMAL', 'Eccentricity': 4.0, 'Closeness Centrality': 0.37178573972505163, 'Harmonic Closeness Centrality': 0.38854296388547555, 'Betweenness Centrality': 4.758333722295284e-06, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 2.6480803, 'r': 115, 'g': 192, 'b': 0, 'x': 722.3473, 'y': 330.57376})
# ('12986', {'label': 'KATH', 'Eccentricity': 4.0, 'Closeness Centrality': 0.37823834196891193, 'Harmonic Closeness Centrality': 0.3959351151132387, 'Betweenness Centrality': 3.742316207915335e-06, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 3.186243, 'r': 115, 'g': 192, 'b': 0, 'x': 711.17236, 'y': 283.399})
# ('12987', {'label': 'NEOPHYTE/', 'Eccentricity': 4.0, 'Closeness Centrality': 0.3835047759000735, 'Harmonic Closeness Centrality': 0.4020180732509843, 'Betweenness Centrality': 7.706495604262869e-06, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 3.186243, 'r': 115, 'g': 192, 'b': 0, 'x': 727.9256, 'y': 260.9463})
# ('12988', {'label': 'FERRIS', 'Eccentricity': 4.0, 'Closeness Centrality': 0.37964141542713753, 'Harmonic Closeness Centrality': 0.39738800012776604, 'Betweenness Centrality': 5.775721243900979e-06, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 3.0427332, 'r': 115, 'g': 192, 'b': 0, 'x': 812.01733, 'y': 222.03505})
# ('12989', {'label': 'MELLENCAMP', 'Eccentricity': 4.0, 'Closeness Centrality': 0.3853309217083164, 'Harmonic Closeness Centrality': 0.40410958904112865, 'Betweenness Centrality': 9.62528462859969e-06, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 3.2221208, 'r': 115, 'g': 192, 'b': 0, 'x': 744.05444, 'y': 249.84607})
# ('12990', {'label': 'ASTRA II', 'Eccentricity': 4.0, 'Closeness Centrality': 0.3723294218354318, 'Harmonic Closeness Centrality': 0.3889580738896268, 'Betweenness Centrality': 6.58398918530677e-06, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 2.612203, 'r': 115, 'g': 192, 'b': 0, 'x': 799.1556, 'y': 264.9856})
# ('12991', {'label': 'JOSEPH', 'Eccentricity': 4.0, 'Closeness Centrality': 0.4471046770601336, 'Harmonic Closeness Centrality': 0.46508286234313484, 'Betweenness Centrality': 0.00037589214002504626, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 4.800731, 'r': 115, 'g': 192, 'b': 0, 'x': 414.26117, 'y': 232.66656})
# ('12992', {'label': ',"VINDALOO/', 'Eccentricity': 5.0, 'Closeness Centrality': 0.33884056089327447, 'Harmonic Closeness Centrality': 0.3630424370150657, 'Betweenness Centrality': 6.996240234949951e-06, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.7511426, 'r': 115, 'g': 192, 'b': 0, 'x': 636.57214, 'y': -144.98392})
# ('12993', {'label': ',"UNUSCIONE', 'Eccentricity': 5.0, 'Closeness Centrality': 0.33927004452533394, 'Harmonic Closeness Centrality': 0.3634735127886073, 'Betweenness Centrality': 7.099701415792903e-06, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.6793876, 'r': 115, 'g': 192, 'b': 0, 'x': 526.23334, 'y': -208.77153})
# ('12994', {'label': ',"HALLER, GABRIELLE', 'Eccentricity': 5.0, 'Closeness Centrality': 0.35016100898966857, 'Harmonic Closeness Centrality': 0.3758773190280321, 'Betweenness Centrality': 1.4522897315019422e-05, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.7511426, 'r': 115, 'g': 192, 'b': 0, 'x': 577.0762, 'y': -137.69177})
# ('12995', {'label': ',"KAMAL', 'Eccentricity': 5.0, 'Closeness Centrality': 0.3326747187609548, 'Harmonic Closeness Centrality': 0.35539483347704987, 'Betweenness Centrality': 3.20932012209458e-06, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.715265, 'r': 115, 'g': 192, 'b': 0, 'x': 687.44684, 'y': -90.9037})
# ('12996', {'label': ',"KATH', 'Eccentricity': 5.0, 'Closeness Centrality': 0.33884056089327447, 'Harmonic Closeness Centrality': 0.3630424370150657, 'Betweenness Centrality': 6.996240234949951e-06, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.7511426, 'r': 115, 'g': 192, 'b': 0, 'x': 611.92566, 'y': -145.32991})
# ('12997', {'label': ',"NEOPHYTE/', 'Eccentricity': 5.0, 'Closeness Centrality': 0.33691582752388327, 'Harmonic Closeness Centrality': 0.3606395887218066, 'Betweenness Centrality': 4.61553514889653e-06, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.7511426, 'r': 115, 'g': 192, 'b': 0, 'x': 599.47, 'y': -84.5271})
# ('12998', {'label': ',"FERRIS', 'Eccentricity': 5.0, 'Closeness Centrality': 0.3368723376791016, 'Harmonic Closeness Centrality': 0.360543794105464, 'Betweenness Centrality': 4.233000719316883e-06, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.715265, 'r': 115, 'g': 192, 'b': 0, 'x': 586.46545, 'y': -82.292015})
# ('12999', {'label': ',"MELLENCAMP', 'Eccentricity': 5.0, 'Closeness Centrality': 0.33691582752388327, 'Harmonic Closeness Centrality': 0.3606395887218066, 'Betweenness Centrality': 4.61553514889653e-06, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.7511426, 'r': 115, 'g': 192, 'b': 0, 'x': 605.2409, 'y': -72.15977})
# ('13000', {'label': ',"ASTRA II', 'Eccentricity': 5.0, 'Closeness Centrality': 0.3326323168594462, 'Harmonic Closeness Centrality': 0.35529903886070724, 'Betweenness Centrality': 2.8942434258928583e-06, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.6793876, 'r': 115, 'g': 192, 'b': 0, 'x': 645.3813, 'y': -120.90748})
# ('13001', {'label': ',"JOSEPH', 'Eccentricity': 4.0, 'Closeness Centrality': 0.39385021694019995, 'Harmonic Closeness Centrality': 0.41972411150494937, 'Betweenness Centrality': 8.090412961369175e-05, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.8587751, 'r': 115, 'g': 192, 'b': 0, 'x': 483.0999, 'y': -110.135635})
# ('13002', {'label': 'MERCURY III/', 'Eccentricity': 4.0, 'Closeness Centrality': 0.36278019113814075, 'Harmonic Closeness Centrality': 0.37704760992436887, 'Betweenness Centrality': 1.285024293783884e-06, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 2.1099176, 'r': 115, 'g': 192, 'b': 0, 'x': 1189.6837, 'y': -13.462515})
# ('13003', {'label': 'REINMAN, PAULA', 'Eccentricity': 4.0, 'Closeness Centrality': 0.3626289644631257, 'Harmonic Closeness Centrality': 0.37682408915290294, 'Betweenness Centrality': 1.1024694385929317e-06, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 2.0740402, 'r': 115, 'g': 192, 'b': 0, 'x': 1176.913, 'y': 2.592633})
# ('13004', {'label': 'RAPTURE/SISTER JOY', 'Eccentricity': 4.0, 'Closeness Centrality': 0.36278019113814075, 'Harmonic Closeness Centrality': 0.37704760992436887, 'Betweenness Centrality': 1.285024293783884e-06, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 2.1099176, 'r': 115, 'g': 192, 'b': 0, 'x': 1202.941, 'y': -2.661956})
# ('13005', {'label': 'CHAOS/DANIEL DASH', 'Eccentricity': 5.0, 'Closeness Centrality': 0.34644232045665735, 'Harmonic Closeness Centrality': 0.3555321390938291, 'Betweenness Centrality': 3.197438534915496e-09, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 2.0022852, 'r': 115, 'g': 192, 'b': 0, 'x': 1203.0905, 'y': 16.560087})
# ('13006', {'label': 'CRUX/CRISTAL LEMIUEX', 'Eccentricity': 4.0, 'Closeness Centrality': 0.3626289644631257, 'Harmonic Closeness Centrality': 0.37682408915290294, 'Betweenness Centrality': 1.1024694385929317e-06, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 2.0740402, 'r': 115, 'g': 192, 'b': 0, 'x': 1146.4973, 'y': 3.7156785})
# ('13007', {'label': 'GREY KING/ADDISON FA', 'Eccentricity': 4.0, 'Closeness Centrality': 0.36278019113814075, 'Harmonic Closeness Centrality': 0.37704760992436887, 'Betweenness Centrality': 1.285024293783884e-06, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 2.1099176, 'r': 115, 'g': 192, 'b': 0, 'x': 1135.5991, 'y': -10.979206})
# ('13008', {'label': 'LANDSLIDE II/LEE BRO', 'Eccentricity': 4.0, 'Closeness Centrality': 0.36278019113814075, 'Harmonic Closeness Centrality': 0.37704760992436887, 'Betweenness Centrality': 1.285024293783884e-06, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 2.1099176, 'r': 115, 'g': 192, 'b': 0, 'x': 1157.2999, 'y': -12.101555})
# ('13009', {'label': ',"REINMAN, PAULA', 'Eccentricity': 5.0, 'Closeness Centrality': 0.3237200359723385, 'Harmonic Closeness Centrality': 0.34395216655492994, 'Betweenness Centrality': 4.632279308667962e-07, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.571755, 'r': 115, 'g': 192, 'b': 0, 'x': 990.4608, 'y': -119.53863})
# ('13010', {'label': ',"RAPTURE/SISTER JOY', 'Eccentricity': 5.0, 'Closeness Centrality': 0.3237200359723385, 'Harmonic Closeness Centrality': 0.34395216655492994, 'Betweenness Centrality': 4.632279308667962e-07, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.571755, 'r': 115, 'g': 192, 'b': 0, 'x': 1092.3157, 'y': -170.67168})
# ('13011', {'label': ',"CHAOS/DANIEL DASH', 'Eccentricity': 5.0, 'Closeness Centrality': 0.3237200359723385, 'Harmonic Closeness Centrality': 0.34395216655492994, 'Betweenness Centrality': 4.632279308667962e-07, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.571755, 'r': 115, 'g': 192, 'b': 0, 'x': 803.75305, 'y': -116.57555})
# ('13012', {'label': ',"CRUX/CRISTAL LEMIUEX', 'Eccentricity': 5.0, 'Closeness Centrality': 0.3237200359723385, 'Harmonic Closeness Centrality': 0.34395216655492994, 'Betweenness Centrality': 4.632279308667962e-07, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.571755, 'r': 115, 'g': 192, 'b': 0, 'x': 987.567, 'y': -114.00623})
# ('13013', {'label': ',"GREY KING/ADDISON FA', 'Eccentricity': 5.0, 'Closeness Centrality': 0.30293093441671504, 'Harmonic Closeness Centrality': 0.31632819235560816, 'Betweenness Centrality': 0.0, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.5, 'r': 115, 'g': 192, 'b': 0, 'x': 1304.351, 'y': -262.48618})
# ('13014', {'label': ',"LANDSLIDE II/LEE BRO', 'Eccentricity': 5.0, 'Closeness Centrality': 0.30293093441671504, 'Harmonic Closeness Centrality': 0.31632819235560816, 'Betweenness Centrality': 0.0, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.5, 'r': 115, 'g': 192, 'b': 0, 'x': 1297.5433, 'y': -266.9197})
# ('13015', {'label': ',"APE MAN/GORDON MONK', 'Eccentricity': 5.0, 'Closeness Centrality': 0.3531700385682387, 'Harmonic Closeness Centrality': 0.3792923971006455, 'Betweenness Centrality': 4.136780550200673e-06, 'Modularity Class': 0, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.571755, 'r': 207, 'g': 128, 'b': 255, 'x': 213.98436, 'y': -525.17993})
# ('13016', {'label': ',"RED GHOST/IVAN KRAGO', 'Eccentricity': 5.0, 'Closeness Centrality': 0.3887606137345449, 'Harmonic Closeness Centrality': 0.41544688188525647, 'Betweenness Centrality': 4.04488305389694e-05, 'Modularity Class': 0, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.6435101, 'r': 207, 'g': 128, 'b': 255, 'x': 36.596764, 'y': -300.48355})
# ('13017', {'label': ',"PEATOR', 'Eccentricity': 5.0, 'Closeness Centrality': 0.3862148063191387, 'Harmonic Closeness Centrality': 0.4130759651307786, 'Betweenness Centrality': 3.263827864046348e-05, 'Modularity Class': 0, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.6435101, 'r': 207, 'g': 128, 'b': 255, 'x': 26.175383, 'y': -450.40674})
# ('13018', {'label': ',"MIKHLO', 'Eccentricity': 5.0, 'Closeness Centrality': 0.4053193554649583, 'Harmonic Closeness Centrality': 0.42984161956765754, 'Betweenness Centrality': 9.053250600622055e-05, 'Modularity Class': 0, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.7870201, 'r': 207, 'g': 128, 'b': 255, 'x': 124.50775, 'y': -470.48666})
# ('13019', {'label': ',"IGOR', 'Eccentricity': 5.0, 'Closeness Centrality': 0.40252178607233746, 'Harmonic Closeness Centrality': 0.4273828910815335, 'Betweenness Centrality': 7.843705667022562e-05, 'Modularity Class': 0, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.7511426, 'r': 207, 'g': 128, 'b': 255, 'x': 117.6424, 'y': -463.13623})
# ('13020', {'label': 'APE MAN/GORDON MONK', 'Eccentricity': 5.0, 'Closeness Centrality': 0.38391379500570044, 'Harmonic Closeness Centrality': 0.40196857936587765, 'Betweenness Centrality': 0.000277549382170314, 'Modularity Class': 7, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.9664077, 'r': 0, 'g': 196, 'b': 255, 'x': 19.315739, 'y': 172.51703})
# ('13021', {'label': 'POSITRON/RONNIE', 'Eccentricity': 4.0, 'Closeness Centrality': 0.40818800344099476, 'Harmonic Closeness Centrality': 0.4289603090973101, 'Betweenness Centrality': 0.0005459180181645261, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 3.3656306, 'r': 115, 'g': 192, 'b': 0, 'x': 397.05438, 'y': -740.62213})
# ('13022', {'label': ',"POSITRON/RONNIE', 'Eccentricity': 5.0, 'Closeness Centrality': 0.38373033377444493, 'Harmonic Closeness Centrality': 0.4108136156081543, 'Betweenness Centrality': 8.3072852496276e-05, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.715265, 'r': 115, 'g': 192, 'b': 0, 'x': 322.90286, 'y': -837.44635})
# ('13023', {'label': ',"TOAD/MORTIMER TOYNBE', 'Eccentricity': 5.0, 'Closeness Centrality': 0.3913842231553689, 'Harmonic Closeness Centrality': 0.41762301625317155, 'Betweenness Centrality': 7.8332262731222e-05, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.7511426, 'r': 115, 'g': 192, 'b': 0, 'x': 167.51775, 'y': -189.73996})
# ('13024', {'label': 'ARIEL II', 'Eccentricity': 4.0, 'Closeness Centrality': 0.3738762938290176, 'Harmonic Closeness Centrality': 0.38982820832140885, 'Betweenness Centrality': 1.4635797436265913e-06, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 2.6480803, 'r': 115, 'g': 192, 'b': 0, 'x': 519.7562, 'y': 658.496})
# ('13025', {'label': 'CHANCE', 'Eccentricity': 4.0, 'Closeness Centrality': 0.36215091066782307, 'Harmonic Closeness Centrality': 0.3755548104863669, 'Betweenness Centrality': 8.317157067223195e-07, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 2.1816728, 'r': 115, 'g': 192, 'b': 0, 'x': 466.10147, 'y': 584.3593})
# ('13026', {'label': 'SILVER SURFER IMPOST', 'Eccentricity': 4.0, 'Closeness Centrality': 0.4132293563454992, 'Harmonic Closeness Centrality': 0.4328320081744876, 'Betweenness Centrality': 1.3471877453060573e-06, 'Modularity Class': 3, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 2.0740402, 'r': 255, 'g': 238, 'b': 87, 'x': -172.6148, 'y': -667.22955})
# ('13027', {'label': ',"DEVIL-SLAYER/ERIC SI', 'Eccentricity': 5.0, 'Closeness Centrality': 0.38832676140168143, 'Harmonic Closeness Centrality': 0.41519142957500893, 'Betweenness Centrality': 4.273989517100024e-05, 'Modularity Class': 6, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.5, 'r': 255, 'g': 136, 'b': 5, 'x': 103.574104, 'y': -509.79498})
# ('13028', {'label': ',"SILVER SURFER IMPOST', 'Eccentricity': 5.0, 'Closeness Centrality': 0.37822463768115944, 'Harmonic Closeness Centrality': 0.40546029313154763, 'Betweenness Centrality': 2.2468472572600835e-05, 'Modularity Class': 0, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.571755, 'r': 207, 'g': 128, 'b': 255, 'x': 236.6879, 'y': -565.6598})
# ('13029', {'label': ',"ELYSIUS', 'Eccentricity': 5.0, 'Closeness Centrality': 0.3569010906355773, 'Harmonic Closeness Centrality': 0.3834450937190956, 'Betweenness Centrality': 8.136391918559285e-06, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.5358775, 'r': 115, 'g': 192, 'b': 0, 'x': 413.6219, 'y': -773.13116})
# ('13030', {'label': ',"IRON FIST/DANIEL RAN', 'Eccentricity': 5.0, 'Closeness Centrality': 0.3990138368626252, 'Harmonic Closeness Centrality': 0.4246128300922962, 'Betweenness Centrality': 0.00028905654742110746, 'Modularity Class': 0, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.9664077, 'r': 207, 'g': 128, 'b': 255, 'x': -88.095505, 'y': -130.66899})
# ('13031', {'label': ',"MULTIPLE MAN/JAMES A', 'Eccentricity': 5.0, 'Closeness Centrality': 0.407980615156134, 'Harmonic Closeness Centrality': 0.43206405466680364, 'Betweenness Centrality': 0.00011179938123786517, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.8228977, 'r': 115, 'g': 192, 'b': 0, 'x': 391.73785, 'y': -170.13026})
# ('13032', {'label': ',"CHANCE', 'Eccentricity': 6.0, 'Closeness Centrality': 0.2969421134973688, 'Harmonic Closeness Centrality': 0.3089583932049847, 'Betweenness Centrality': 0.0, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.5, 'r': 115, 'g': 192, 'b': 0, 'x': 1175.8883, 'y': -200.49007})
# ('13033', {'label': ',"SIRYN/THERESA ROURKE', 'Eccentricity': 5.0, 'Closeness Centrality': 0.36167411564979385, 'Harmonic Closeness Centrality': 0.38839128907624926, 'Betweenness Centrality': 8.472905057394164e-05, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 2.0022852, 'r': 115, 'g': 192, 'b': 0, 'x': 570.5756, 'y': -16.752188})
# ('13034', {'label': ',"BOWMAN, MAJ.', 'Eccentricity': 5.0, 'Closeness Centrality': 0.3160460187708144, 'Harmonic Closeness Centrality': 0.33372289810648387, 'Betweenness Centrality': 0.0, 'Modularity Class': 4, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.5, 'r': 255, 'g': 85, 'b': 132, 'x': 233.65744, 'y': 802.7912})
# ('13035', {'label': 'BOWMAN, MAJ.', 'Eccentricity': 4.0, 'Closeness Centrality': 0.3927832336230575, 'Harmonic Closeness Centrality': 0.41072740045346035, 'Betweenness Centrality': 1.2064948349889939e-06, 'Modularity Class': 4, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.6761883, 'r': 255, 'g': 85, 'b': 132, 'x': -806.5566, 'y': -221.41333})
# ('13036', {'label': ',"DUNCAN, FRED', 'Eccentricity': 5.0, 'Closeness Centrality': 0.32582165485814163, 'Harmonic Closeness Centrality': 0.34646198550310764, 'Betweenness Centrality': 2.2984230684341066e-06, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.6076325, 'r': 115, 'g': 192, 'b': 0, 'x': 787.4439, 'y': -174.2189})
# ('13037', {'label': 'DUNCAN, FRED', 'Eccentricity': 4.0, 'Closeness Centrality': 0.36829664126446515, 'Harmonic Closeness Centrality': 0.3834419005652375, 'Betweenness Centrality': 2.2060617420045954e-06, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 2.0381627, 'r': 115, 'g': 192, 'b': 0, 'x': 233.86496, 'y': 515.11194})
# ('13038', {'label': 'JIGSAW', 'Eccentricity': 4.0, 'Closeness Centrality': 0.36607518586056953, 'Harmonic Closeness Centrality': 0.380871411693377, 'Betweenness Centrality': 0.00010314594886970568, 'Modularity Class': 7, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 2.4328153, 'r': 0, 'g': 196, 'b': 255, 'x': -753.17456, 'y': 1581.5548})
# ('13039', {'label': 'MCCOY, EDNA ANDREWS', 'Eccentricity': 4.0, 'Closeness Centrality': 0.3904181314982422, 'Harmonic Closeness Centrality': 0.40909090909093826, 'Betweenness Centrality': 2.7255899943655485e-05, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 2.4686928, 'r': 115, 'g': 192, 'b': 0, 'x': 178.37834, 'y': 701.96594})
# ('13040', {'label': 'EL CONQUISTADOR', 'Eccentricity': 4.0, 'Closeness Centrality': 0.3615112896523064, 'Harmonic Closeness Centrality': 0.3750678545199572, 'Betweenness Centrality': 1.3558377395769993e-06, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.715265, 'r': 115, 'g': 192, 'b': 0, 'x': 243.20534, 'y': 599.1738})
# ('13041', {'label': 'MCCOY, NORTON', 'Eccentricity': 4.0, 'Closeness Centrality': 0.3846352247605011, 'Harmonic Closeness Centrality': 0.4026646869112979, 'Betweenness Centrality': 1.5563990707417233e-05, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 2.1099176, 'r': 115, 'g': 192, 'b': 0, 'x': 118.51784, 'y': 719.14886})
# ('13042', {'label': ',"MCCOY, EDNA ANDREWS', 'Eccentricity': 5.0, 'Closeness Centrality': 0.32043096568236235, 'Harmonic Closeness Centrality': 0.3396909027046263, 'Betweenness Centrality': 7.127217567690709e-07, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.571755, 'r': 115, 'g': 192, 'b': 0, 'x': 622.1768, 'y': 3.8613057})
# ('13043', {'label': ',"EL CONQUISTADOR', 'Eccentricity': 5.0, 'Closeness Centrality': 0.3197537292859987, 'Harmonic Closeness Centrality': 0.3387569051952863, 'Betweenness Centrality': 1.8396570511011024e-07, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.5358775, 'r': 115, 'g': 192, 'b': 0, 'x': 633.56024, 'y': -246.23138})
# ('13044', {'label': ',"MCCOY, NORTON', 'Eccentricity': 5.0, 'Closeness Centrality': 0.32043096568236235, 'Harmonic Closeness Centrality': 0.3396909027046263, 'Betweenness Centrality': 7.127217567690709e-07, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.571755, 'r': 115, 'g': 192, 'b': 0, 'x': 838.9901, 'y': 79.03195})
# ('13045', {'label': ',"SHADOW KING/AMAHL FA', 'Eccentricity': 5.0, 'Closeness Centrality': 0.351304055190981, 'Harmonic Closeness Centrality': 0.376988536577605, 'Betweenness Centrality': 1.2431367902625867e-05, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.6793876, 'r': 115, 'g': 192, 'b': 0, 'x': 694.49567, 'y': -176.42442})
# ('13046', {'label': ',"ORPHAN-MAKER/PETER', 'Eccentricity': 5.0, 'Closeness Centrality': 0.33825864359547647, 'Harmonic Closeness Centrality': 0.3617524028483216, 'Betweenness Centrality': 5.489090737240379e-06, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.5358775, 'r': 115, 'g': 192, 'b': 0, 'x': 630.4553, 'y': -288.2409})
# ('13047', {'label': 'CARTER, BRAD', 'Eccentricity': 5.0, 'Closeness Centrality': 0.3328125996301728, 'Harmonic Closeness Centrality': 0.3389197560430848, 'Betweenness Centrality': 4.5207637886068715e-06, 'Modularity Class': 17, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 2.7536564, 'r': 192, 'g': 192, 'b': 192, 'x': -1305.6166, 'y': -858.10065})
# ('13048', {'label': 'KABALLA', 'Eccentricity': 5.0, 'Closeness Centrality': 0.3455707097457627, 'Harmonic Closeness Centrality': 0.3541542931954362, 'Betweenness Centrality': 0.0002991435934201595, 'Modularity Class': 17, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 2.702925, 'r': 192, 'g': 192, 'b': 192, 'x': -1546.1567, 'y': -1467.5712})
# ('13049', {'label': 'DOCKERY, RUPERT', 'Eccentricity': 5.0, 'Closeness Centrality': 0.3502079978529254, 'Harmonic Closeness Centrality': 0.3603250630648368, 'Betweenness Centrality': 1.560240552050114e-07, 'Modularity Class': 7, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.7511426, 'r': 0, 'g': 196, 'b': 255, 'x': -1053.9495, 'y': 853.0137})
# ('13050', {'label': 'MAYE, APRIL', 'Eccentricity': 4.0, 'Closeness Centrality': 0.3627675840978593, 'Harmonic Closeness Centrality': 0.3768400549222953, 'Betweenness Centrality': 5.4801622911387476e-06, 'Modularity Class': 7, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 2.5045705, 'r': 0, 'g': 196, 'b': 255, 'x': -980.6611, 'y': 1130.1333})
# ('13051', {'label': 'MULLANY, MIKE', 'Eccentricity': 5.0, 'Closeness Centrality': 0.3500670690811536, 'Harmonic Closeness Centrality': 0.36000574767702814, 'Betweenness Centrality': 1.4316490238658502e-08, 'Modularity Class': 7, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.715265, 'r': 0, 'g': 196, 'b': 255, 'x': -1078.4579, 'y': 1188.3784})
# ('13052', {'label': 'BUSHKIN, BARNEY', 'Eccentricity': 4.0, 'Closeness Centrality': 0.3781972320846316, 'Harmonic Closeness Centrality': 0.3964460197337355, 'Betweenness Centrality': 4.193010085928062e-05, 'Modularity Class': 7, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 3.0427332, 'r': 0, 'g': 196, 'b': 255, 'x': -960.5995, 'y': 995.3357})
# ('13053', {'label': 'WHITMAN, DEBRA', 'Eccentricity': 4.0, 'Closeness Centrality': 0.39134020618556703, 'Harmonic Closeness Centrality': 0.41111057891883274, 'Betweenness Centrality': 6.377893834755832e-05, 'Modularity Class': 7, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 3.4732633, 'r': 0, 'g': 196, 'b': 255, 'x': -883.55597, 'y': 867.6813})
# ('13054', {'label': 'JONES, SANDY', 'Eccentricity': 4.0, 'Closeness Centrality': 0.3682706554716715, 'Harmonic Closeness Centrality': 0.3837771817224359, 'Betweenness Centrality': 2.458866903050829e-06, 'Modularity Class': 7, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 2.7915905, 'r': 0, 'g': 196, 'b': 255, 'x': -1051.5189, 'y': 1170.0964})
# ('13055', {'label': ',"MAYE, APRIL', 'Eccentricity': 5.0, 'Closeness Centrality': 0.302150568757417, 'Harmonic Closeness Centrality': 0.3166155762046339, 'Betweenness Centrality': 0.0, 'Modularity Class': 7, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.5, 'r': 0, 'g': 196, 'b': 255, 'x': -799.5978, 'y': 1623.1383})
# ('13056', {'label': ',"BUSHKIN, BARNEY', 'Eccentricity': 5.0, 'Closeness Centrality': 0.30565396890463503, 'Harmonic Closeness Centrality': 0.32131270555929875, 'Betweenness Centrality': 4.3786059973784996e-07, 'Modularity Class': 7, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.5358775, 'r': 0, 'g': 196, 'b': 255, 'x': -684.0337, 'y': 1183.0535})
# ('13057', {'label': 'BAXTER, ABIGAIL', 'Eccentricity': 4.0, 'Closeness Centrality': 0.3771723813997182, 'Harmonic Closeness Centrality': 0.39365201009041434, 'Betweenness Centrality': 5.638918384968136e-07, 'Modularity Class': 4, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 2.0872943, 'r': 255, 'g': 85, 'b': 132, 'x': -678.93036, 'y': 313.92593})
# ('13058', {'label': 'HELLSCOUT/KENNETH TE', 'Eccentricity': 4.0, 'Closeness Centrality': 0.3787873290032294, 'Harmonic Closeness Centrality': 0.3954002618386638, 'Betweenness Centrality': 5.462640305744768e-07, 'Modularity Class': 4, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 2.2047532, 'r': 255, 'g': 85, 'b': 132, 'x': -548.2143, 'y': 177.46913})
# ('13059', {'label': 'AWESOME ANDROID', 'Eccentricity': 4.0, 'Closeness Centrality': 0.39156039009752436, 'Harmonic Closeness Centrality': 0.41001692371558474, 'Betweenness Centrality': 3.80757095219385e-06, 'Modularity Class': 4, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 2.2634826, 'r': 255, 'g': 85, 'b': 132, 'x': -860.1006, 'y': 140.0358})
# ('13060', {'label': 'BAXTER, NOAH', 'Eccentricity': 4.0, 'Closeness Centrality': 0.40063708934602393, 'Harmonic Closeness Centrality': 0.41985982054477367, 'Betweenness Centrality': 2.1063411081504833e-05, 'Modularity Class': 4, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 2.7920475, 'r': 255, 'g': 85, 'b': 132, 'x': -668.14575, 'y': 304.31073})
# ('13061', {'label': 'JANUS', 'Eccentricity': 4.0, 'Closeness Centrality': 0.3745604592752063, 'Harmonic Closeness Centrality': 0.3906584283297115, 'Betweenness Centrality': 1.5447987528749121e-06, 'Modularity Class': 4, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 2.439671, 'r': 255, 'g': 85, 'b': 132, 'x': -481.03592, 'y': 324.83075})
# ('13062', {'label': 'GORNKAI', 'Eccentricity': 4.0, 'Closeness Centrality': 0.3718122239635276, 'Harmonic Closeness Centrality': 0.38736149695058864, 'Betweenness Centrality': 8.92142756042882e-07, 'Modularity Class': 4, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 2.2047532, 'r': 255, 'g': 85, 'b': 132, 'x': -554.72, 'y': 163.66182})
# ('13063', {'label': ',"HELLSCOUT/KENNETH TE', 'Eccentricity': 5.0, 'Closeness Centrality': 0.3209136462848535, 'Harmonic Closeness Centrality': 0.34027684644125533, 'Betweenness Centrality': 5.335756558808708e-07, 'Modularity Class': 4, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.5587294, 'r': 255, 'g': 85, 'b': 132, 'x': 79.3013, 'y': -104.07544})
# ('13064', {'label': ',"AWESOME ANDROID', 'Eccentricity': 5.0, 'Closeness Centrality': 0.3160460187708144, 'Harmonic Closeness Centrality': 0.33372289810648387, 'Betweenness Centrality': 0.0, 'Modularity Class': 4, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.5, 'r': 255, 'g': 85, 'b': 132, 'x': 517.2096, 'y': -903.5378})
# ('13065', {'label': ',"BAXTER, NOAH', 'Eccentricity': 5.0, 'Closeness Centrality': 0.3160460187708144, 'Harmonic Closeness Centrality': 0.33372289810648387, 'Betweenness Centrality': 0.0, 'Modularity Class': 4, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.5, 'r': 255, 'g': 85, 'b': 132, 'x': -21.36572, 'y': -54.66592})
# ('13066', {'label': ',"MAXIMUS [INHUMAN]', 'Eccentricity': 5.0, 'Closeness Centrality': 0.3618872633987381, 'Harmonic Closeness Centrality': 0.38891336973531737, 'Betweenness Centrality': 1.0880752569204722e-05, 'Modularity Class': 4, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.5587294, 'r': 255, 'g': 85, 'b': 132, 'x': -9.068466, 'y': -218.92464})
# ('13067', {'label': ',"JANUS', 'Eccentricity': 5.0, 'Closeness Centrality': 0.3160460187708144, 'Harmonic Closeness Centrality': 0.33372289810648387, 'Betweenness Centrality': 0.0, 'Modularity Class': 4, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.5, 'r': 255, 'g': 85, 'b': 132, 'x': -19.670069, 'y': -56.89585})
# ('13068', {'label': 'HARROW, DR. JONAS', 'Eccentricity': 4.0, 'Closeness Centrality': 0.3708084683148622, 'Harmonic Closeness Centrality': 0.38668295175149414, 'Betweenness Centrality': 2.1382353164815115e-06, 'Modularity Class': 7, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 2.3969378, 'r': 0, 'g': 196, 'b': 255, 'x': -887.5353, 'y': 1139.2491})
# ('13069', {'label': ',"GORNKAI', 'Eccentricity': 5.0, 'Closeness Centrality': 0.3160460187708144, 'Harmonic Closeness Centrality': 0.33372289810648387, 'Betweenness Centrality': 0.0, 'Modularity Class': 4, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.5, 'r': 255, 'g': 85, 'b': 132, 'x': 180.0913, 'y': -446.607})
# ('13070', {'label': 'TENNYSON, JACOB', 'Eccentricity': 4.0, 'Closeness Centrality': 0.3748698243976012, 'Harmonic Closeness Centrality': 0.3906344796756251, 'Betweenness Centrality': 0.0, 'Modularity Class': 4, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.8523766, 'r': 255, 'g': 85, 'b': 132, 'x': -815.20215, 'y': 465.44238})
# ('13071', {'label': 'OLSEN, JIMMY', 'Eccentricity': 4.0, 'Closeness Centrality': 0.36843962870151414, 'Harmonic Closeness Centrality': 0.3833141744101136, 'Betweenness Centrality': 2.7621665278707264e-06, 'Modularity Class': 7, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.7511426, 'r': 0, 'g': 196, 'b': 255, 'x': -613.81537, 'y': 1154.8254})
# ('13072', {'label': 'ALLEN, TERRY', 'Eccentricity': 5.0, 'Closeness Centrality': 0.3608739240156255, 'Harmonic Closeness Centrality': 0.3738161381997489, 'Betweenness Centrality': 0.0, 'Modularity Class': 4, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.7936472, 'r': 255, 'g': 85, 'b': 132, 'x': -443.92856, 'y': 896.2485})
# ('13073', {'label': ',"DIAMOND, BOB', 'Eccentricity': 5.0, 'Closeness Centrality': 0.31856327626720377, 'Harmonic Closeness Centrality': 0.3371156241019505, 'Betweenness Centrality': 1.7669092600345612e-06, 'Modularity Class': 0, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.5358775, 'r': 207, 'g': 128, 'b': 255, 'x': 35.87453, 'y': -735.553})
# ('13074', {'label': ',"OLSEN, JIMMY', 'Eccentricity': 5.0, 'Closeness Centrality': 0.3160460187708144, 'Harmonic Closeness Centrality': 0.33372289810648387, 'Betweenness Centrality': 0.0, 'Modularity Class': 4, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.5, 'r': 255, 'g': 85, 'b': 132, 'x': 504.04327, 'y': -911.0918})
# ('13075', {'label': ',"ALLEN, TERRY', 'Eccentricity': 5.0, 'Closeness Centrality': 0.3160460187708144, 'Harmonic Closeness Centrality': 0.33372289810648387, 'Betweenness Centrality': 0.0, 'Modularity Class': 4, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.5, 'r': 255, 'g': 85, 'b': 132, 'x': 515.9558, 'y': -899.5113})
# ('13076', {'label': 'STELLARAX', 'Eccentricity': 5.0, 'Closeness Centrality': 0.3365899271296834, 'Harmonic Closeness Centrality': 0.34347957978099347, 'Betweenness Centrality': 0.0, 'Modularity Class': 3, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.6435101, 'r': 255, 'g': 238, 'b': 87, 'x': -358.54416, 'y': -704.6002})
# ('13077', {'label': ',"SWORDSMAN/JACQUES DU', 'Eccentricity': 5.0, 'Closeness Centrality': 0.3813054753990576, 'Harmonic Closeness Centrality': 0.4085384934700218, 'Betweenness Centrality': 4.8906163828901985e-05, 'Modularity Class': 0, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.8587751, 'r': 207, 'g': 128, 'b': 255, 'x': -186.21562, 'y': -368.2085})
# ('13078', {'label': 'RAVEN, SABBATH', 'Eccentricity': 5.0, 'Closeness Centrality': 0.3624149423691154, 'Harmonic Closeness Centrality': 0.3754845611010493, 'Betweenness Centrality': 5.709665488167581e-07, 'Modularity Class': 7, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.6793876, 'r': 0, 'g': 196, 'b': 255, 'x': -1270.183, 'y': 766.8635})
# ('13079', {'label': 'PATHWAY/LAURA DEAN', 'Eccentricity': 4.0, 'Closeness Centrality': 0.42338578844905905, 'Harmonic Closeness Centrality': 0.4434811763578953, 'Betweenness Centrality': 0.00010336108730296354, 'Modularity Class': 14, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 4.833638, 'r': 255, 'g': 49, 'b': 20, 'x': 393.56128, 'y': -552.5333})
# ('13080', {'label': 'JADE DRAGON/DEI GUAN', 'Eccentricity': 4.0, 'Closeness Centrality': 0.3953118491309123, 'Harmonic Closeness Centrality': 0.414056263371358, 'Betweenness Centrality': 3.250322450707029e-05, 'Modularity Class': 14, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 3.5146253, 'r': 255, 'g': 49, 'b': 20, 'x': 636.63586, 'y': -397.55722})
# ('13081', {'label': 'GOBLYN', 'Eccentricity': 4.0, 'Closeness Centrality': 0.42126715092816786, 'Harmonic Closeness Centrality': 0.44127790018201873, 'Betweenness Centrality': 8.95819818532502e-05, 'Modularity Class': 14, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 4.6560783, 'r': 255, 'g': 49, 'b': 20, 'x': 423.51163, 'y': -559.4196})
# ('13082', {'label': ',"JADE DRAGON/DEI GUAN', 'Eccentricity': 5.0, 'Closeness Centrality': 0.29664677465188977, 'Harmonic Closeness Centrality': 0.3071335057636592, 'Betweenness Centrality': 1.9077171866900477e-08, 'Modularity Class': 14, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 2.5253656, 'r': 255, 'g': 49, 'b': 20, 'x': 844.549, 'y': -992.8309})
# ('13083', {'label': 'SNAKE', 'Eccentricity': 5.0, 'Closeness Centrality': 0.3389946093394817, 'Harmonic Closeness Centrality': 0.3473496822812337, 'Betweenness Centrality': 1.7858546757525036e-06, 'Modularity Class': 14, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 3.0073128, 'r': 255, 'g': 49, 'b': 20, 'x': 926.00653, 'y': -368.71408})
# ('13084', {'label': 'OX IV', 'Eccentricity': 5.0, 'Closeness Centrality': 0.33855484205746905, 'Harmonic Closeness Centrality': 0.3466791199668355, 'Betweenness Centrality': 1.5529731446471867e-06, 'Modularity Class': 14, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 2.981947, 'r': 255, 'g': 49, 'b': 20, 'x': 1023.50885, 'y': -306.22522})
# ('13085', {'label': 'RAT', 'Eccentricity': 5.0, 'Closeness Centrality': 0.3308821198770167, 'Harmonic Closeness Centrality': 0.3372209981799428, 'Betweenness Centrality': 1.0416850311704363e-08, 'Modularity Class': 14, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 2.8043876, 'r': 255, 'g': 49, 'b': 20, 'x': 804.2734, 'y': -654.9317})
# ('13086', {'label': 'RABBIT', 'Eccentricity': 5.0, 'Closeness Centrality': 0.3389946093394817, 'Harmonic Closeness Centrality': 0.3473496822812337, 'Betweenness Centrality': 1.7858546757525036e-06, 'Modularity Class': 14, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 3.0073128, 'r': 255, 'g': 49, 'b': 20, 'x': 942.54675, 'y': -368.93042})
# ('13087', {'label': ',"OX IV', 'Eccentricity': 6.0, 'Closeness Centrality': 0.27639069077815137, 'Harmonic Closeness Centrality': 0.28328703260210536, 'Betweenness Centrality': 0.0, 'Modularity Class': 14, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 2.5, 'r': 255, 'g': 49, 'b': 20, 'x': 974.76245, 'y': -1153.8206})
# ('13088', {'label': ',"PATHWAY/LAURA DEAN', 'Eccentricity': 5.0, 'Closeness Centrality': 0.3532178385328551, 'Harmonic Closeness Centrality': 0.3787096465178948, 'Betweenness Centrality': 1.0062552363563505e-05, 'Modularity Class': 14, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 2.7282906, 'r': 255, 'g': 49, 'b': 20, 'x': 418.45483, 'y': -541.12964})
# ('13089', {'label': ',"GOBLYN', 'Eccentricity': 5.0, 'Closeness Centrality': 0.3515406634113487, 'Harmonic Closeness Centrality': 0.3765782163042731, 'Betweenness Centrality': 7.171001583465218e-06, 'Modularity Class': 14, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 2.702925, 'r': 255, 'g': 49, 'b': 20, 'x': 446.7361, 'y': -562.5151})
# ('13090', {'label': ',"PURPLE MAN/ZEBEDIAH', 'Eccentricity': 5.0, 'Closeness Centrality': 0.35076106313631933, 'Harmonic Closeness Centrality': 0.37684324807615405, 'Betweenness Centrality': 7.960077424004687e-06, 'Modularity Class': 0, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.6793876, 'r': 207, 'g': 128, 'b': 255, 'x': 183.50072, 'y': -810.18414})
# ('13091', {'label': 'PARALYZER', 'Eccentricity': 4.0, 'Closeness Centrality': 0.4052721484587313, 'Harmonic Closeness Centrality': 0.42536002809977, 'Betweenness Centrality': 2.260211675912495e-05, 'Modularity Class': 6, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 2.2175503, 'r': 255, 'g': 136, 'b': 5, 'x': -434.84085, 'y': 153.24141})
# ('13092', {'label': 'CRUCIBLE/BYRON CALLE', 'Eccentricity': 4.0, 'Closeness Centrality': 0.41016070095477586, 'Harmonic Closeness Centrality': 0.43080435546190193, 'Betweenness Centrality': 3.943545873009986e-05, 'Modularity Class': 6, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 2.2175503, 'r': 255, 'g': 136, 'b': 5, 'x': -531.5427, 'y': 140.19887})
# ('13093', {'label': 'SLITHER', 'Eccentricity': 4.0, 'Closeness Centrality': 0.4035955924995167, 'Harmonic Closeness Centrality': 0.423691605198472, 'Betweenness Centrality': 2.4813507016759504e-05, 'Modularity Class': 6, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 2.2175503, 'r': 255, 'g': 136, 'b': 5, 'x': -599.27216, 'y': 103.29971})
# ('13094', {'label': 'METEORITE', 'Eccentricity': 4.0, 'Closeness Centrality': 0.409661721999843, 'Harmonic Closeness Centrality': 0.4297985119903061, 'Betweenness Centrality': 2.6041808275059574e-05, 'Modularity Class': 6, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 2.2175503, 'r': 255, 'g': 136, 'b': 5, 'x': -410.77924, 'y': 167.77643})
# ('13095', {'label': 'OCCULT', 'Eccentricity': 4.0, 'Closeness Centrality': 0.4091960330837678, 'Harmonic Closeness Centrality': 0.4297266660280501, 'Betweenness Centrality': 4.190600847697964e-05, 'Modularity Class': 6, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 2.0740402, 'r': 255, 'g': 136, 'b': 5, 'x': -437.98666, 'y': 384.27887})
# ('13096', {'label': ',"CRUCIBLE/BYRON CALLE', 'Eccentricity': 5.0, 'Closeness Centrality': 0.35291930085533657, 'Harmonic Closeness Centrality': 0.37938180540923155, 'Betweenness Centrality': 8.549330435232635e-06, 'Modularity Class': 0, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.571755, 'r': 207, 'g': 128, 'b': 255, 'x': 52.99415, 'y': -643.57465})
# ('13097', {'label': ',"SLITHER', 'Eccentricity': 5.0, 'Closeness Centrality': 0.3469835466179159, 'Harmonic Closeness Centrality': 0.3726282849570808, 'Betweenness Centrality': 5.2401988169893186e-06, 'Modularity Class': 0, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.5358775, 'r': 207, 'g': 128, 'b': 255, 'x': 67.485504, 'y': -484.21732})
# ('13098', {'label': 'AQUARIAN/WUNDARR', 'Eccentricity': 4.0, 'Closeness Centrality': 0.4105478428442207, 'Harmonic Closeness Centrality': 0.43087620142415944, 'Betweenness Centrality': 2.3487307839770206e-05, 'Modularity Class': 4, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 2.4984004, 'r': 255, 'g': 85, 'b': 132, 'x': -644.6116, 'y': 78.91464})
# ('13099', {'label': 'WILBURN, MYRON', 'Eccentricity': 4.0, 'Closeness Centrality': 0.4012530750307503, 'Harmonic Closeness Centrality': 0.4198917520835553, 'Betweenness Centrality': 3.910647568706967e-06, 'Modularity Class': 4, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.7349178, 'r': 255, 'g': 85, 'b': 132, 'x': -586.2274, 'y': -720.8777})
# ('13100', {'label': 'FANG', 'Eccentricity': 5.0, 'Closeness Centrality': 0.35178944530565476, 'Harmonic Closeness Centrality': 0.36188172558040566, 'Betweenness Centrality': 0.0, 'Modularity Class': 3, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.5358775, 'r': 255, 'g': 238, 'b': 87, 'x': -1048.226, 'y': -691.10406})
# ('13101', {'label': 'RAPIER', 'Eccentricity': 5.0, 'Closeness Centrality': 0.36510212646894236, 'Harmonic Closeness Centrality': 0.379731455758904, 'Betweenness Centrality': 4.249276668927381e-06, 'Modularity Class': 3, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 2.1816728, 'r': 255, 'g': 238, 'b': 87, 'x': -1589.7878, 'y': 612.67004})
# ...
# ('17936', {'label': 'GODSTALKER', 'Eccentricity': 5.0, 'Closeness Centrality': 0.33690495401000486, 'Harmonic Closeness Centrality': 0.34382284382288714, 'Betweenness Centrality': 7.3069025168968526e-06, 'Modularity Class': 3, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 2.0381627, 'r': 255, 'g': 238, 'b': 87, 'x': 69.03624, 'y': -1672.287})
# ('17937', {'label': "SHYM'R", 'Eccentricity': 5.0, 'Closeness Centrality': 0.3024569739815727, 'Harmonic Closeness Centrality': 0.3099993613692417, 'Betweenness Centrality': 0.0, 'Modularity Class': 3, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.8228977, 'r': 255, 'g': 238, 'b': 87, 'x': 185.73386, 'y': -1916.8875})
# ('17938', {'label': 'ZEY-ROGG', 'Eccentricity': 5.0, 'Closeness Centrality': 0.3341977205788193, 'Harmonic Closeness Centrality': 0.34096497110199997, 'Betweenness Centrality': 6.853041944711653e-06, 'Modularity Class': 3, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.8228977, 'r': 255, 'g': 238, 'b': 87, 'x': 104.68294, 'y': -1403.7034})
# ('17939', {'label': 'BAV-TEK', 'Eccentricity': 5.0, 'Closeness Centrality': 0.3024569739815727, 'Harmonic Closeness Centrality': 0.3099993613692417, 'Betweenness Centrality': 0.0, 'Modularity Class': 3, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.8228977, 'r': 255, 'g': 238, 'b': 87, 'x': 176.92764, 'y': -1916.2728})
# ('17940', {'label': 'HAV-ROGG', 'Eccentricity': 5.0, 'Closeness Centrality': 0.3024569739815727, 'Harmonic Closeness Centrality': 0.3099993613692417, 'Betweenness Centrality': 0.0, 'Modularity Class': 3, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.8228977, 'r': 255, 'g': 238, 'b': 87, 'x': 167.86311, 'y': -1919.734})
# ('17941', {'label': 'JELLA, PRIVATE', 'Eccentricity': 5.0, 'Closeness Centrality': 0.3411549397039119, 'Harmonic Closeness Centrality': 0.34935977264749013, 'Betweenness Centrality': 2.4171435570030808e-05, 'Modularity Class': 3, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 2.2175503, 'r': 255, 'g': 238, 'b': 87, 'x': 129.4698, 'y': -1588.2722})
# ('17942', {'label': 'PHILLIPS, SIR GORDON', 'Eccentricity': 4.0, 'Closeness Centrality': 0.3670018281535649, 'Harmonic Closeness Centrality': 0.38164575150881236, 'Betweenness Centrality': 1.618382778232955e-07, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 2.4686928, 'r': 115, 'g': 192, 'b': 0, 'x': 1019.1975, 'y': 509.39737})
# ('17943', {'label': ',"PHILLIPS, SIR GORDON', 'Eccentricity': 5.0, 'Closeness Centrality': 0.3264329716376372, 'Harmonic Closeness Centrality': 0.3473927898585679, 'Betweenness Centrality': 3.7097914353632445e-07, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.5358775, 'r': 115, 'g': 192, 'b': 0, 'x': 1036.4985, 'y': -297.35718})
# ('17944', {'label': ',"MACTAGGART, JOE', 'Eccentricity': 5.0, 'Closeness Centrality': 0.3002214489085732, 'Harmonic Closeness Centrality': 0.3128077402050183, 'Betweenness Centrality': 0.0, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.5, 'r': 115, 'g': 192, 'b': 0, 'x': 1357.1354, 'y': -139.22034})
# ('17945', {'label': 'MACTAGGART, JOE', 'Eccentricity': 4.0, 'Closeness Centrality': 0.37137571596285884, 'Harmonic Closeness Centrality': 0.386866558099482, 'Betweenness Centrality': 3.7097914353632445e-07, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 2.0022852, 'r': 115, 'g': 192, 'b': 0, 'x': 1009.7765, 'y': 150.55302})
# ('17946', {'label': 'VAVELLA', 'Eccentricity': 5.0, 'Closeness Centrality': 0.3024394483717696, 'Harmonic Closeness Centrality': 0.30990356675289915, 'Betweenness Centrality': 0.0, 'Modularity Class': 3, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.7511426, 'r': 255, 'g': 238, 'b': 87, 'x': 169.4548, 'y': -1938.6718})
# ('17947', {'label': "LYTH'KA, COMMANDER", 'Eccentricity': 5.0, 'Closeness Centrality': 0.3024394483717696, 'Harmonic Closeness Centrality': 0.30990356675289915, 'Betweenness Centrality': 0.0, 'Modularity Class': 3, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.7511426, 'r': 255, 'g': 238, 'b': 87, 'x': 177.55606, 'y': -1935.2123})
# ('17948', {'label': "MYLZOB'RYN, CHIEF", 'Eccentricity': 5.0, 'Closeness Centrality': 0.3024394483717696, 'Harmonic Closeness Centrality': 0.30990356675289915, 'Betweenness Centrality': 0.0, 'Modularity Class': 3, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.7511426, 'r': 255, 'g': 238, 'b': 87, 'x': 185.58113, 'y': -1937.2133})
# ('17949', {'label': 'PRIMO, ALEXIS', 'Eccentricity': 5.0, 'Closeness Centrality': 0.32834271695027206, 'Harmonic Closeness Centrality': 0.33416993964943, 'Betweenness Centrality': 7.960210673114748e-06, 'Modularity Class': 7, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.6435101, 'r': 0, 'g': 196, 'b': 255, 'x': -1506.6464, 'y': 984.5944})
# ('17950', {'label': 'PIRANHA II/', 'Eccentricity': 5.0, 'Closeness Centrality': 0.3272926791033077, 'Harmonic Closeness Centrality': 0.3329246096369759, 'Betweenness Centrality': 0.0, 'Modularity Class': 7, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.571755, 'r': 0, 'g': 196, 'b': 255, 'x': -1298.2021, 'y': 1122.3656})
# ('17951', {'label': 'ADAM X', 'Eccentricity': 5.0, 'Closeness Centrality': 0.3591975775927328, 'Harmonic Closeness Centrality': 0.3719848644506657, 'Betweenness Centrality': 8.36009571874337e-06, 'Modularity Class': 5, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.8946526, 'r': 115, 'g': 192, 'b': 0, 'x': 607.8258, 'y': -692.27704})
# ('17952', {'label': 'KLAER', 'Eccentricity': 5.0, 'Closeness Centrality': 0.34103234237177393, 'Harmonic Closeness Centrality': 0.34883290225760605, 'Betweenness Centrality': 0.0, 'Modularity Class': 3, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.8228977, 'r': 255, 'g': 238, 'b': 87, 'x': 62.56799, 'y': -1261.8971})
# ('17953', {'label': 'HAV-AK', 'Eccentricity': 5.0, 'Closeness Centrality': 0.34103234237177393, 'Harmonic Closeness Centrality': 0.34883290225760605, 'Betweenness Centrality': 0.0, 'Modularity Class': 3, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.8228977, 'r': 255, 'g': 238, 'b': 87, 'x': 76.26596, 'y': -1249.4615})
# ('17954', {'label': 'HELKOOKY', 'Eccentricity': 5.0, 'Closeness Centrality': 0.34103234237177393, 'Harmonic Closeness Centrality': 0.34883290225760605, 'Betweenness Centrality': 0.0, 'Modularity Class': 3, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.8228977, 'r': 255, 'g': 238, 'b': 87, 'x': 75.46618, 'y': -1259.9818})
# ('17955', {'label': 'SMASHER', 'Eccentricity': 5.0, 'Closeness Centrality': 0.3395238404995772, 'Harmonic Closeness Centrality': 0.34617939138491594, 'Betweenness Centrality': 0.0, 'Modularity Class': 7, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.5358775, 'r': 0, 'g': 196, 'b': 255, 'x': -1217.7229, 'y': 987.78375})
# ('17956', {'label': ',"TAGAK', 'Eccentricity': 5.0, 'Closeness Centrality': 0.3395901106050748, 'Harmonic Closeness Centrality': 0.3635852731743448, 'Betweenness Centrality': 6.03114615451401e-06, 'Modularity Class': 0, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.6076325, 'r': 207, 'g': 128, 'b': 255, 'x': -23.01081, 'y': -890.4434})
# ('17957', {'label': ',"LOOTER/NORTON G. FES', 'Eccentricity': 5.0, 'Closeness Centrality': 0.35133952611739366, 'Harmonic Closeness Centrality': 0.37728390331133216, 'Betweenness Centrality': 1.7238785175918552e-05, 'Modularity Class': 0, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.6076325, 'r': 207, 'g': 128, 'b': 255, 'x': -372.86154, 'y': 336.27673})
# ('17958', {'label': 'LUNATIK/ARISEN TYRK', 'Eccentricity': 4.0, 'Closeness Centrality': 0.39567145510366525, 'Harmonic Closeness Centrality': 0.4142558354887414, 'Betweenness Centrality': 1.4818086202942812e-05, 'Modularity Class': 6, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.9664077, 'r': 255, 'g': 136, 'b': 5, 'x': -736.0459, 'y': -145.1738})
# ('17959', {'label': ',"LUNATIK/ARISEN TYRK', 'Eccentricity': 5.0, 'Closeness Centrality': 0.31354939476766885, 'Harmonic Closeness Centrality': 0.33055688603636046, 'Betweenness Centrality': 2.4771851775341835e-07, 'Modularity Class': 6, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.5, 'r': 255, 'g': 136, 'b': 5, 'x': 12.573498, 'y': -1237.3824})
# ('17960', {'label': ',"DOLLAR BILL', 'Eccentricity': 5.0, 'Closeness Centrality': 0.3353895582329317, 'Harmonic Closeness Centrality': 0.35881629785742086, 'Betweenness Centrality': 1.8020957833431643e-06, 'Modularity Class': 0, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.5358775, 'r': 207, 'g': 128, 'b': 255, 'x': -86.304146, 'y': -1136.8506})
# ('17961', {'label': 'MARISTA', 'Eccentricity': 5.0, 'Closeness Centrality': 0.3359400141597477, 'Harmonic Closeness Centrality': 0.3427148194271919, 'Betweenness Centrality': 0.0, 'Modularity Class': 4, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.9698355, 'r': 255, 'g': 85, 'b': 132, 'x': -1224.5719, 'y': -195.13206})
# ('17962', {'label': 'RYNDA', 'Eccentricity': 5.0, 'Closeness Centrality': 0.3359400141597477, 'Harmonic Closeness Centrality': 0.3427148194271919, 'Betweenness Centrality': 0.0, 'Modularity Class': 4, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.9698355, 'r': 255, 'g': 85, 'b': 132, 'x': -1214.0953, 'y': -207.58626})
# ('17963', {'label': 'AGON', 'Eccentricity': 5.0, 'Closeness Centrality': 0.3359400141597477, 'Harmonic Closeness Centrality': 0.3427148194271919, 'Betweenness Centrality': 0.0, 'Modularity Class': 4, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.9698355, 'r': 255, 'g': 85, 'b': 132, 'x': -1216.4227, 'y': -197.39915})
# ('17964', {'label': 'SPIRAL II/ESTELLE GE', 'Eccentricity': 5.0, 'Closeness Centrality': 0.34353506433672293, 'Harmonic Closeness Centrality': 0.35140019797558797, 'Betweenness Centrality': 0.0, 'Modularity Class': 10, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 20.301645, 'r': 173, 'g': 255, 'b': 253, 'x': -1307.6084, 'y': -1309.3921})
# ('17965', {'label': 'RAZORFIST IV/MARCO S', 'Eccentricity': 5.0, 'Closeness Centrality': 0.34353506433672293, 'Harmonic Closeness Centrality': 0.35140019797558797, 'Betweenness Centrality': 0.0, 'Modularity Class': 10, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 20.301645, 'r': 173, 'g': 255, 'b': 253, 'x': -1300.8832, 'y': -1315.5994})
# ('17966', {'label': 'CARLTON, JAKE', 'Eccentricity': 5.0, 'Closeness Centrality': 0.35040784129435065, 'Harmonic Closeness Centrality': 0.3604288405658745, 'Betweenness Centrality': 0.0, 'Modularity Class': 7, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.8228977, 'r': 0, 'g': 196, 'b': 255, 'x': -1031.0111, 'y': 1638.3837})
# ('17967', {'label': 'COFFY, DET.', 'Eccentricity': 5.0, 'Closeness Centrality': 0.35076106313631933, 'Harmonic Closeness Centrality': 0.36103553980271075, 'Betweenness Centrality': 6.672982856479806e-08, 'Modularity Class': 7, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.9664077, 'r': 0, 'g': 196, 'b': 255, 'x': -980.1043, 'y': 1501.1721})
# ('17968', {'label': 'CARLTON, LUCY', 'Eccentricity': 5.0, 'Closeness Centrality': 0.35040784129435065, 'Harmonic Closeness Centrality': 0.3604288405658745, 'Betweenness Centrality': 0.0, 'Modularity Class': 7, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.8228977, 'r': 0, 'g': 196, 'b': 255, 'x': -1038.8593, 'y': 1631.4829})
# ('17969', {'label': 'WILLIAMS, NILES', 'Eccentricity': 5.0, 'Closeness Centrality': 0.35040784129435065, 'Harmonic Closeness Centrality': 0.3604288405658745, 'Betweenness Centrality': 0.0, 'Modularity Class': 7, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.8228977, 'r': 0, 'g': 196, 'b': 255, 'x': -1043.3243, 'y': 1639.4634})
# ('17970', {'label': ',"GHOST', 'Eccentricity': 5.0, 'Closeness Centrality': 0.3222709310940973, 'Harmonic Closeness Centrality': 0.3423236580771075, 'Betweenness Centrality': 0.0, 'Modularity Class': 0, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.5, 'r': 207, 'g': 128, 'b': 255, 'x': -310.9009, 'y': -868.3584})
# ('17971', {'label': ',"PEMBROKE', 'Eccentricity': 5.0, 'Closeness Centrality': 0.3263411279229711, 'Harmonic Closeness Centrality': 0.3474965673596074, 'Betweenness Centrality': 7.467171213883392e-07, 'Modularity Class': 0, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.5358775, 'r': 207, 'g': 128, 'b': 255, 'x': -1278.2366, 'y': -524.17725})
# ('17972', {'label': ',"HALE, JONAS', 'Eccentricity': 5.0, 'Closeness Centrality': 0.3263411279229711, 'Harmonic Closeness Centrality': 0.3474965673596074, 'Betweenness Centrality': 7.467171213883392e-07, 'Modularity Class': 0, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.5358775, 'r': 207, 'g': 128, 'b': 255, 'x': -1172.5343, 'y': -237.81992})
# ('17973', {'label': ',"STILETTO', 'Eccentricity': 5.0, 'Closeness Centrality': 0.3327595550030283, 'Harmonic Closeness Centrality': 0.3554092026695049, 'Betweenness Centrality': 1.6472270867848938e-06, 'Modularity Class': 0, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.571755, 'r': 207, 'g': 128, 'b': 255, 'x': -1034.8645, 'y': -229.1948})
# ('17974', {'label': ',"DISCUS', 'Eccentricity': 5.0, 'Closeness Centrality': 0.337831715210356, 'Harmonic Closeness Centrality': 0.36168375003994346, 'Betweenness Centrality': 2.485997783177303e-06, 'Modularity Class': 0, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.6076325, 'r': 207, 'g': 128, 'b': 255, 'x': -919.6505, 'y': -338.6594})
# ('17975', {'label': ',"BOMBSHELL/', 'Eccentricity': 5.0, 'Closeness Centrality': 0.3201754385964912, 'Harmonic Closeness Centrality': 0.3394434332790746, 'Betweenness Centrality': 4.0484498341831774e-07, 'Modularity Class': 0, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.5358775, 'r': 207, 'g': 128, 'b': 255, 'x': -1212.3784, 'y': -525.4615})
# ('17976', {'label': 'ADAMS, CONGRESSMAN H', 'Eccentricity': 5.0, 'Closeness Centrality': 0.35071392575172183, 'Harmonic Closeness Centrality': 0.3608439505700256, 'Betweenness Centrality': 0.0, 'Modularity Class': 7, 'Grado': 0, 'Authority': 0.0, 'Hub': 0.0, 'PageRank': 0.0, 'Component ID': 0, 'size': 1.8228977, 'r': 0, 'g': 196, 'b': 255, 'x': -990.4015, 'y': 1566.7202})
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
# Centralidad de intermediación
btwnCent = nx.betweenness_centrality(G, k=50)

# %%
aux = sorted(btwnCent.items(), key=operator.itemgetter(1), reverse=True)[0:10]
for x in aux:
    print(G.nodes[x[0]]["label"], "=" ,x[1], "centralidad de intermediación")
# Out:
# IRON MAN/TONY STARK = 0.07610057454130695 centralidad de intermediación
# SCARLET WITCH/WANDA = 0.054874484134241674 centralidad de intermediación
# FURY, COL. NICHOLAS = 0.049281933164846844 centralidad de intermediación
# HAVOK/ALEX SUMMERS = 0.047780774680396446 centralidad de intermediación
# WOLVERINE/LOGAN = 0.04765555554285542 centralidad de intermediación
# WASP/JANET VAN DYNE = 0.0451331415595736 centralidad de intermediación
# SPIDER-MAN/PETER PAR = 0.041660671450653115 centralidad de intermediación
# INVISIBLE WOMAN/SUE = 0.04053113040819788 centralidad de intermediación
# PROFESSOR X/CHARLES = 0.03966915165429787 centralidad de intermediación
# DR. STRANGE/STEPHEN = 0.03857663908986585 centralidad de intermediación

# %% [markdown]
# # Centralidad de cercanía

# %%
# Centralidad de cercanía
closCent = nx.closeness_centrality(G)

# %%
aux = sorted(closCent.items(), key=operator.itemgetter(1), reverse=True)[0:10]
for x in aux:
    print(G.nodes[x[0]]["label"], "=" ,x[1], "centralidad de cercanía")
# Out:
# CAPTAIN AMERICA = 0.5393265122828756 centralidad de cercanía
# SPIDER-MAN/PETER PAR = 0.5348926287166821 centralidad de cercanía
# THING/BENJAMIN J. GR = 0.5249662299588536 centralidad de cercanía
# MR. FANTASTIC/REED R = 0.5244637180756746 centralidad de cercanía
# HUMAN TORCH/JOHNNY S = 0.5228043561713572 centralidad de cercanía
# THOR/DR. DONALD BLAK = 0.5212859459230879 centralidad de cercanía
# BEAST/HENRY &HANK& P = 0.51894717547777 centralidad de cercanía
# HULK/DR. ROBERT BRUC = 0.5156823866886643 centralidad de cercanía
# HAWK = 0.5139765152603963 centralidad de cercanía
# CYCLOPS/SCOTT SUMMER = 0.5133935167965707 centralidad de cercanía

# %% [markdown]
# ***
# # Hits

# %%
hits = nx.hits(G)

# %%
aux = sorted(hits[0].items(), key=operator.itemgetter(1), reverse=True)[0:10]
for x in aux:
    print(G.nodes[x[0]]["label"], "=" ,x[1], "Hits")
# Out:
# CAPTAIN AMERICA = 0.013855257140673262 Hits
# INVISIBLE WOMAN/SUE = 0.012592623463794056 Hits
# THING/BENJAMIN J. GR = 0.012383237118246845 Hits
# HUMAN TORCH/JOHNNY S = 0.01206093693846407 Hits
# MR. FANTASTIC/REED R = 0.01188927825904918 Hits
# IRON MAN/TONY STARK = 0.011069636394950497 Hits
# THOR/DR. DONALD BLAK = 0.01005866998906248 Hits
# SCARLET WITCH/WANDA = 0.009969719088135296 Hits
# VISION = 0.009724857730474847 Hits
# WASP/JANET VAN DYNE = 0.009512837449481283 Hits

# %% [markdown]
# # PageRank

# %%
page_rank = nx.pagerank(G)

# %%
aux = sorted(page_rank.items(), key=operator.itemgetter(1), reverse=True)[0:10]
for x in aux:
    print(G.nodes[x[0]]["label"], "=" ,x[1], "Page rank")
# Out:
# IRON MAN/TONY STARK = 0.012668117378978662 Page rank
# WOLVERINE/LOGAN = 0.011053959968329289 Page rank
# INVISIBLE WOMAN/SUE = 0.01030138195920518 Page rank
# SCARLET WITCH/WANDA = 0.009397909290880033 Page rank
# VISION = 0.008822151826105296 Page rank
# WATSON-PARKER, MARY = 0.008374412602233336 Page rank
# CAPTAIN AMERICA = 0.008325842199658245 Page rank
# SPIDER-MAN/PETER PAR = 0.007880331735873176 Page rank
# WASP/JANET VAN DYNE = 0.007531427032802924 Page rank
# PROFESSOR X/CHARLES = 0.007484751313948101 Page rank

# %% [markdown]
# # Clustering

# %%
G_cluster = nx.average_clustering(G, count_zeros=False) #se puede añadir un weight average_clustering(G, nodes=None, weight=None, count_zeros=True)

# %%
print("Clustering average:", G_cluster) #Con count zeros da 0,45... Sin da 0,748... que se acerca más al valor de Gephi
# Out:
# Clustering average: 0.7486268944775251

# %% [markdown]
# ***
# # Comunidades

# %%
#todo lo de abajo funciona regu
partition = community_louvain.best_partition(G)

# %%
max(partition.values())
# Out:
# 31

# %%
list1 = []
list2 = []
list3 = []
list4 = []
list5 = []
list6 = []

aux = sorted(G.degree, key=lambda x: x[1], reverse=True)[0:3000]
for x in aux:
    if (partition[x[0]] == 0):
        list1.append(G.nodes[x[0]]["label"])
    elif (partition[x[0]] == 1):
        list2.append(G.nodes[x[0]]["label"])
    elif (partition[x[0]] == 2):
        list3.append(G.nodes[x[0]]["label"])
    elif (partition[x[0]] == 5):
        list4.append(G.nodes[x[0]]["label"])
    elif (partition[x[0]] == 6):
        list5.append(G.nodes[x[0]]["label"])
    elif (partition[x[0]] == 10):
        list6.append(G.nodes[x[0]]["label"])

# %%
#Capitan America
list1[0:10]
# Out:
# []

# %%
#Spider-verse
list2[0:10]
# Out:
# ['CAPTAIN AMERICA',
#  'HAWK',
#  'ANT-MAN/DR. HENRY J.',
#  'SHE-HULK/JENNIFER WA',
#  'WONDER MAN/SIMON WIL',
#  'HERCULES [GREEK GOD]',
#  'QUICKSILVER/PIETRO M',
#  'QUASAR III/WENDELL V',
#  "BLACK PANTHER/T'CHAL",
#  'CRYSTAL [INHUMAN]']

# %%
#Avengers
list3[0:10]
# Out:
# ['SPIDER-MAN/PETER PAR',
#  'WATSON-PARKER, MARY',
#  'DAREDEVIL/MATT MURDO',
#  'JAMESON, J. JONAH',
#  'ROBERTSON, JOE',
#  'NELSON, FRANKLIN FOG',
#  'PARKER, MAY',
#  'PUNISHER II/FRANK CA',
#  'KINGPIN/WILSON FISK',
#  'JAMESON, COL. JOHN']

# %%
#Hulk and Dr. Strange
list4[0:10]
# Out:
# ['ROM, SPACEKNIGHT',
#  'STARSHINE II/BRANDY',
#  'TORPEDO III/BROCK JO',
#  'JACKSON, STEVE',
#  'LOCKLIN, GENERAL MER',
#  'JONES, LORRAINE LORR',
#  'JONES, DANIEL DANNY',
#  'JONES, TAMMY ANNE',
#  'CLARK, SARAH',
#  'CLARK, JOHN']

# %%
#X-men
list5[0:10]
# Out:
# []

# %%
#Fantasic 4
list6[0:10]
# Out:
# []
